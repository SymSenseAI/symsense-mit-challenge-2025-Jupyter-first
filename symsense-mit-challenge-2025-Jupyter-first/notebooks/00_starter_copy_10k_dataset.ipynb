# %% [markdown]
# # SymSense MIT Challenge: Jupyter Starter
#
# This notebook checks your environment, sets a data path, and loads a small CSV to verify everything works.

# %%
import sys, os, platform
print("Python:", sys.version)
print("Platform:", platform.platform())
try:
    import numpy, pandas, sklearn
    print("NumPy:", numpy.__version__)
    print("pandas:", pandas.__version__)
    print("scikit-learn:", sklearn.__version__)
except Exception as e:
    print("Import error:", e)

# %% [markdown]
# ## Configure data path
# Set `SYMSENSE_DATA` environment variable to the shared dataset folder or use a local fallback.

# %%
import os, pandas as pd
DATA_ROOT = os.getenv("SYMSENSE_DATA", "/Users/hongmei_yu/symsense-mit-challenge-2025-Jupyter-first/symsense-mit-challenge-2025-Jupyter-first/data/raw")
print("DATA_ROOT:", DATA_ROOT)
# Example: try reading a small CSV if present
example = os.path.join(DATA_ROOT, "example.csv")
if os.path.exists(example):
    df = pd.read_csv(example)
    display(df.head())
else:
    print("Place a small CSV at:", example)

# %% [markdown]
# ## Next steps
# - Add your dataset subset to `data/raw/` or set `SYMSENSE_DATA`.
# - Open `01_exploration.ipynb` to begin EDA.
# - Use `make setup` to enable nbstripout so notebook outputs are not committed.
